# %%
import pandas as pd
from config import api_key
import requests
import json
from yelp.client import Client

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'
 
# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'restaurant','location':'New York City'}

# Making a get request to the API
req=requests.get(url, params=params, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
sample = json.loads(req.text)

# %%
print(json.dumps(sample, indent=4))
# Out:
# {
#     "businesses": [
#         {
#             "id": "ehUuSk5gPTCQmwS_ubgKRA",
#             "alias": "upstate-new-york-2",
#             "name": "Upstate",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 1768,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 },
#                 {
#                     "alias": "beerbar",
#                     "title": "Beer Bar"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7263139141197,
#                 "longitude": -73.9864901976935
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "95 1st Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10003",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "95 1st Ave",
#                     "New York, NY 10003"
#                 ]
#             },
#             "phone": "+16467915400",
#             "display_phone": "(646) 791-5400",
#             "distance": 2411.9187177986864
#         },
#         {
#             "id": "ETgJqJHV7BW6pIr9Ox74sA",
#             "alias": "am\u00e9lie-new-york",
#             "name": "Am\u00e9lie",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 2536,
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7327,
#                 "longitude": -73.99766
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "22 W 8th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10011",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "22 W 8th St",
#                     "New York, NY 10011"
#                 ]
#             },
#             "phone": "+12125332962",
#             "display_phone": "(212) 533-2962",
#             "distance": 3038.8699032940094
#         },
#         {
#             "id": "xZ96vaoL-cQjfotmUKtjJQ",
#             "alias": "barn-joo-35-new-york",
#             "name": "Barn Joo 35",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/1R5CgYlK5qGUhKZOvZThKw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 1664,
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "gastropubs",
#                     "title": "Gastropubs"
#                 },
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.74964,
#                 "longitude": -73.98582
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "34 W 35th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10001",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "34 W 35th St",
#                     "New York, NY 10001"
#                 ]
#             },
#             "phone": "+12125644430",
#             "display_phone": "(212) 564-4430",
#             "distance": 4968.473297353009
#         },
#         {
#             "id": "nU4XBdvxDABXqZ6CnB8Dig",
#             "alias": "clinton-street-baking-company-new-york-5",
#             "name": "Clinton Street Baking Company",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 4813,
#             "categories": [
#                 {
#                     "alias": "bakeries",
#                     "title": "Bakeries"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.721128,
#                 "longitude": -73.983933
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "4 Clinton St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10002",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "4 Clinton St",
#                     "New York, NY 10002"
#                 ]
#             },
#             "phone": "+16466026263",
#             "display_phone": "(646) 602-6263",
#             "distance": 1950.282829638887
#         },
#         {
#             "id": "jjJc_CrkB2HodEinB6cWww",
#             "alias": "lovemama-new-york",
#             "name": "LoveMama",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/lovemama-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 4491,
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "malaysian",
#                     "title": "Malaysian"
#                 },
#                 {
#                     "alias": "vietnamese",
#                     "title": "Vietnamese"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7303859,
#                 "longitude": -73.9860613
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "174 2nd Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10003",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "174 2nd Ave",
#                     "New York, NY 10003"
#                 ]
#             },
#             "phone": "+12122545370",
#             "display_phone": "(212) 254-5370",
#             "distance": 2858.7729410008346
#         },
#         {
#             "id": "B3_K2kUVbYOU0VaLcj_LTw",
#             "alias": "thai-villa-new-york-2",
#             "name": "Thai Villa",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/OgCU9NPFIl8hF_04Zani9w/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 2805,
#             "categories": [
#                 {
#                     "alias": "thai",
#                     "title": "Thai"
#                 },
#                 {
#                     "alias": "asianfusion",
#                     "title": "Asian Fusion"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.73902,
#                 "longitude": -73.99065
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "5 E 19th St",
#                 "address2": "G Floor",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10003",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "5 E 19th St",
#                     "G Floor",
#                     "New York, NY 10003"
#                 ]
#             },
#             "phone": "+12128029999",
#             "display_phone": "(212) 802-9999",
#             "distance": 3744.570399827637
#         },
#         {
#             "id": "CwOAKJdX8AMz5iAoA-ZEuA",
#             "alias": "uglyduckling-brooklyn",
#             "name": "Uglyduckling",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/sCDU8uosDuxp26wjxq4p4g/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/uglyduckling-brooklyn?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 456,
#             "categories": [
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 },
#                 {
#                     "alias": "gastropubs",
#                     "title": "Gastropubs"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.686023,
#                 "longitude": -73.991302
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "166 Smith St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Brooklyn",
#                 "zip_code": "11201",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "166 Smith St",
#                     "Brooklyn, NY 11201"
#                 ]
#             },
#             "phone": "+17184513825",
#             "display_phone": "(718) 451-3825",
#             "distance": 2174.2838817065267
#         },
#         {
#             "id": "C2o3Iw-DXjoUJFgQIbiqkQ",
#             "alias": "bocaph\u00ea-new-york-3",
#             "name": "BoCaphe",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 1235,
#             "categories": [
#                 {
#                     "alias": "vietnamese",
#                     "title": "Vietnamese"
#                 },
#                 {
#                     "alias": "breakfast_brunch",
#                     "title": "Breakfast & Brunch"
#                 },
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.722046,
#                 "longitude": -73.997557
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "222 Lafayette St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10012",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "222 Lafayette St",
#                     "New York, NY 10012"
#                 ]
#             },
#             "phone": "+16468821939",
#             "display_phone": "(646) 882-1939",
#             "distance": 1866.3436634084576
#         },
#         {
#             "id": "FlZ1zdVEKWv7dwqm8Uw8-w",
#             "alias": "raku-new-york-7",
#             "name": "Raku",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/raku-new-york-7?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 940,
#             "categories": [
#                 {
#                     "alias": "japanese",
#                     "title": "Japanese"
#                 },
#                 {
#                     "alias": "noodles",
#                     "title": "Noodles"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7264988089246,
#                 "longitude": -73.9866526052356
#             },
#             "transactions": [
#                 "delivery",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "342 E 6th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10003",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "342 E 6th St",
#                     "New York, NY 10003"
#                 ]
#             },
#             "phone": "+12122281324",
#             "display_phone": "(212) 228-1324",
#             "distance": 2428.0392489129867
#         },
#         {
#             "id": "UA2M9QFZghe-9th2KwLoWQ",
#             "alias": "burger-and-lobster-new-york-4",
#             "name": "Burger & Lobster",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/1rHd7F4zztAsScwzM0vDmw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 5240,
#             "categories": [
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 },
#                 {
#                     "alias": "burgers",
#                     "title": "Burgers"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.74007,
#                 "longitude": -73.99344
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "39 W 19th St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10011",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "39 W 19th St",
#                     "New York, NY 10011"
#                 ]
#             },
#             "phone": "+16468337532",
#             "display_phone": "(646) 833-7532",
#             "distance": 3852.2188529432046
#         },
#         {
#             "id": "0CjK3esfpFcxIopebzjFxA",
#             "alias": "joes-shanghai-new-york-2",
#             "name": "Joe's Shanghai",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 5909,
#             "categories": [
#                 {
#                     "alias": "shanghainese",
#                     "title": "Shanghainese"
#                 },
#                 {
#                     "alias": "seafood",
#                     "title": "Seafood"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.7146691442891,
#                 "longitude": -73.9977602206654
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "9 Pell St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10013",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "9 Pell St",
#                     "New York, NY 10013"
#                 ]
#             },
#             "phone": "+12122338888",
#             "display_phone": "(212) 233-8888",
#             "distance": 1066.5085498349097
#         },
#         {
#             "id": "xt4sa64WOrpJvZBDPNPNYg",
#             "alias": "jacobs-pickles-new-york",
#             "name": "Jacob's Pickles",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/167Rl2s1oMge_2ZSDD1z0A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 3855,
#             "categories": [
#                 {
#                     "alias": "comfortfood",
#                     "title": "Comfort Food"
#                 },
#                 {
#                     "alias": "southern",
#                     "title": "Southern"
#                 },
#                 {
#                     "alias": "tradamerican",
#                     "title": "American (Traditional)"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.7866504411994,
#                 "longitude": -73.9755284786224
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "509 Amsterdam Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10024",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "509 Amsterdam Ave",
#                     "New York, NY 10024"
#                 ]
#             },
#             "phone": "+12124705566",
#             "display_phone": "(212) 470-5566",
#             "distance": 9166.964737863183
#         },
#         {
#             "id": "qm1J_dPA5IHij1oAnoZwHw",
#             "alias": "nonono-new-york-6",
#             "name": "nonono",
#             "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/yhZYzx5cnn8SFFF8eZdRHw/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 472,
#             "categories": [
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 },
#                 {
#                     "alias": "izakaya",
#                     "title": "Izakaya"
#                 },
#                 {
#                     "alias": "ramen",
#                     "title": "Ramen"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.74545,
#                 "longitude": -73.98499
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "118 Madison Ave",
#                 "address2": "",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10016",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "118 Madison Ave",
#                     "New York, NY 10016"
#                 ]
#             },
#             "phone": "+16467073227",
#             "display_phone": "(646) 707-3227",
#             "distance": 4515.897681612123
#         },
#         {
#             "id": "VvsZAnEwU4c8Xkyrzx05Nw",
#             "alias": "anytime-new-york",
#             "name": "Anytime",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/S-K4D44wXoqw-wTL4kX2cQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/anytime-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 771,
#             "categories": [
#                 {
#                     "alias": "korean",
#                     "title": "Korean"
#                 },
#                 {
#                     "alias": "newamerican",
#                     "title": "American (New)"
#                 },
#                 {
#                     "alias": "tapasmallplates",
#                     "title": "Tapas/Small Plates"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.74779,
#                 "longitude": -73.98674
#             },
#             "transactions": [
#                 "restaurant_reservation"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "23 W 32nd St",
#                 "address2": "Fl 3",
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10001",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "23 W 32nd St",
#                     "Fl 3",
#                     "New York, NY 10001"
#                 ]
#             },
#             "phone": "+16466697733",
#             "display_phone": "(646) 669-7733",
#             "distance": 4761.966725883583
#         },
#         {
#             "id": "I2lgw_7DUnwD92ND4PN-Ow",
#             "alias": "aunt-jakes-new-york",
#             "name": "Aunt Jake's",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/hMhn_lnES3QWc4Gtihvr0A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 1326,
#             "categories": [
#                 {
#                     "alias": "italian",
#                     "title": "Italian"
#                 },
#                 {
#                     "alias": "wine_bars",
#                     "title": "Wine Bars"
#                 },
#                 {
#                     "alias": "pastashops",
#                     "title": "Pasta Shops"
#                 }
#             ],
#             "rating": 4.0,
#             "coordinates": {
#                 "latitude": 40.7190315,
#                 "longitude": -73.9977161
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "149 Mulberry St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10013",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "149 Mulberry St",
#                     "New York, NY 10013"
#                 ]
#             },
#             "phone": "+16468580470",
#             "display_phone": "(646) 858-0470",
#             "distance": 1538.0627375870665
#         },
#         {
#             "id": "s3jou_L_LVYGkNHiuhjlew",
#             "alias": "boucherie-west-village-new-york-3",
#             "name": "Boucherie West Village",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-5TXMVrjARsqKQHDg-hKbQ/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 1196,
#             "categories": [
#                 {
#                     "alias": "french",
#                     "title": "French"
#                 },
#                 {
#                     "alias": "cocktailbars",
#                     "title": "Cocktail Bars"
#                 },
#                 {
#                     "alias": "steak",
#                     "title": "Steakhouses"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.733063,
#                 "longitude": -74.0028772
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$$",
#             "location": {
#                 "address1": "99 7th Ave S",
#                 "address2": "",
#                 "address3": null,
#                 "city": "New York",
#                 "zip_code": "10014",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "99 7th Ave S",
#                     "New York, NY 10014"
#                 ]
#             },
#             "phone": "+12128371616",
#             "display_phone": "(212) 837-1616",
#             "distance": 3155.0505772747442
#         },
#         {
#             "id": "0dDCDQz7DrKkSvu9h2hcQw",
#             "alias": "chow-house-new-york",
#             "name": "Chow House",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/kzeClsI9_2tkHqKScotx1Q/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/chow-house-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 308,
#             "categories": [
#                 {
#                     "alias": "chinese",
#                     "title": "Chinese"
#                 },
#                 {
#                     "alias": "noodles",
#                     "title": "Noodles"
#                 },
#                 {
#                     "alias": "soup",
#                     "title": "Soup"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.72915,
#                 "longitude": -74.00072
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "181 Bleecker St",
#                 "address2": null,
#                 "address3": "",
#                 "city": "New York",
#                 "zip_code": "10012",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "181 Bleecker St",
#                     "New York, NY 10012"
#                 ]
#             },
#             "phone": "+12128371021",
#             "display_phone": "(212) 837-1021",
#             "distance": 2692.4401801037266
#         },
#         {
#             "id": "XipQLDbyTl5tsLlyzAWzug",
#             "alias": "jajaja-new-york",
#             "name": "Jajaja",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/QaIhCEp1FpU3a2teWQh6mA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/jajaja-new-york?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 771,
#             "categories": [
#                 {
#                     "alias": "mexican",
#                     "title": "Mexican"
#                 },
#                 {
#                     "alias": "vegan",
#                     "title": "Vegan"
#                 },
#                 {
#                     "alias": "bars",
#                     "title": "Bars"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7141530317142,
#                 "longitude": -73.9904247969389
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "162 E Broadway",
#                 "address2": "",
#                 "address3": null,
#                 "city": "New York",
#                 "zip_code": "10002",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "162 E Broadway",
#                     "New York, NY 10002"
#                 ]
#             },
#             "phone": "+16468835453",
#             "display_phone": "(646) 883-5453",
#             "distance": 1021.7274074140097
#         },
#         {
#             "id": "i6RhqnCJ_oUfTu5LikGXUg",
#             "alias": "dun-huang-east-village-new-york-8",
#             "name": "Dun Huang - East Village",
#             "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/_aTrBIGDOF5GSDJpEGoF7A/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/dun-huang-east-village-new-york-8?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 252,
#             "categories": [
#                 {
#                     "alias": "chinese",
#                     "title": "Chinese"
#                 },
#                 {
#                     "alias": "bbq",
#                     "title": "Barbeque"
#                 },
#                 {
#                     "alias": "noodles",
#                     "title": "Noodles"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.73081,
#                 "longitude": -73.98568
#             },
#             "transactions": [
#                 "delivery",
#                 "restaurant_reservation",
#                 "pickup"
#             ],
#             "price": "$$",
#             "location": {
#                 "address1": "300 E 12th St",
#                 "address2": "",
#                 "address3": null,
#                 "city": "New York",
#                 "zip_code": "10003",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "300 E 12th St",
#                     "New York, NY 10003"
#                 ]
#             },
#             "phone": "+12122543817",
#             "display_phone": "(212) 254-3817",
#             "distance": 2908.2544225724664
#         },
#         {
#             "id": "ysqgdbSrezXgVwER2kQWKA",
#             "alias": "julianas-pizza-brooklyn-5",
#             "name": "Juliana's Pizza",
#             "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w",
#             "review_count": 2061,
#             "categories": [
#                 {
#                     "alias": "pizza",
#                     "title": "Pizza"
#                 }
#             ],
#             "rating": 4.5,
#             "coordinates": {
#                 "latitude": 40.7026153030093,
#                 "longitude": -73.9934159993549
#             },
#             "transactions": [],
#             "price": "$$",
#             "location": {
#                 "address1": "19 Old Fulton St",
#                 "address2": "",
#                 "address3": "",
#                 "city": "Brooklyn",
#                 "zip_code": "11201",
#                 "country": "US",
#                 "state": "NY",
#                 "display_address": [
#                     "19 Old Fulton St",
#                     "Brooklyn, NY 11201"
#                 ]
#             },
#             "phone": "+17185966700",
#             "display_phone": "(718) 596-6700",
#             "distance": 323.20506308227306
#         }
#     ],
#     "total": 18900,
#     "region": {
#         "center": {
#             "longitude": -73.99429321289062,
#             "latitude": 40.70544486444615
#         }
#     }
# }
