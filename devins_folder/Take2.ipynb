# %%
import csv
import matplotlib.pyplot as plt 
import requests
import json
import pandas as pd 
from config import api_key
from yelpapi import YelpAPI
import argparse

from pprint import pprint

argparser = argparse.ArgumentParser(description='Example Yelp queries using yelpapi. Visit https://www.yelp.com/developers/v3/manage_app to get the necessary API keys.')
argparser.add_argument(api_key, type=str, help='Yelp Fusion API Key')
# Out:
# _StoreAction(option_strings=[], dest='VpAqdsRiA4HvlGHzH0toLKhZZSQL2An4bkyl1sK6g2Hn-KScAF1xxAKb3wkFfxrioeKYvFRY5RtMBeEt3hngOhFIQTvPOgzrotLLzkAGAk6X3GtlVSxIL31Ov5NmXXYx', nargs=None, const=None, default=None, type=<class 'str'>, choices=None, help='Yelp Fusion API Key', metavar=None)

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for "Mexican restaurants"
search_results = yelp_api.search_query(term='mexican', location='miami, fl', sort_by='rating', limit=5)
pprint (search_results)
# Out:
# {'businesses': [{'alias': 'antojitos-mexicanos-tenorio-miami',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.730775,
#                                  'longitude': -80.4153515},
#                  'display_phone': '(305) 225-5125',
#                  'distance': 12979.074151727023,
#                  'id': 'UBWFHeS_Y4VpTWpv49ak7g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/txmuw514Aej7NPrGeYJyzQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4095 SW 137th Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['4095 SW 137th Ave',
#                                                   'Miami, FL 33175'],
#                               'state': 'FL',
#                               'zip_code': '33175'},
#                  'name': 'Antojitos Mexicanos Tenorio',
#                  'phone': '+13052255125',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 262,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/antojitos-mexicanos-tenorio-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'taqueria-viva-méxico-miami-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.7686015253466,
#                                  'longitude': -80.2145662531257},
#                  'display_phone': '(786) 350-6360',
#                  'distance': 7570.501680482599,
#                  'id': '9PEF_qX-3FU4iMmKgk98eA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/25JmaQRZadEc_8STVQEKcA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '502 SW 12th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['502 SW 12th Ave',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Taqueria Viva México',
#                  'phone': '+17863506360',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 416,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/taqueria-viva-m%C3%A9xico-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'a-mari-mix-fresh-mex-fusion-miami',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.7468571893715,
#                                  'longitude': -80.3519500632294},
#                  'display_phone': '(305) 603-9134',
#                  'distance': 6429.709695253538,
#                  'id': 'j0MnMGOdiPscmQ-JIILoag',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mnwz2Mh7j2SpOkABrez52w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9700 SW 24th St',
#                               'address2': 'Ste D',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['9700 SW 24th St',
#                                                   'Ste D',
#                                                   'Miami, FL 33165'],
#                               'state': 'FL',
#                               'zip_code': '33165'},
#                  'name': 'A-Mari-Mix Fresh Mex Fusion',
#                  'phone': '+13056039134',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 223,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/a-mari-mix-fresh-mex-fusion-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'el-donkey-mexican-grill-miami',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.701584,
#                                  'longitude': -80.3570983},
#                  'display_phone': '(305) 200-3935',
#                  'distance': 8895.862482317949,
#                  'id': 'nh4td0-yIzXoimKlityncA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mAfQ9Cj2w0-5wagXHucGkA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '10043 SW 72nd St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['10043 SW 72nd St',
#                                                   'Miami, FL 33173'],
#                               'state': 'FL',
#                               'zip_code': '33173'},
#                  'name': 'El Donkey Mexican Grill',
#                  'phone': '+13052003935',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 210,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/el-donkey-mexican-grill-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'tacos-and-tattoos-miami-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'streetvendors',
#                                  'title': 'Street Vendors'}],
#                  'coordinates': {'latitude': 25.6711452954603,
#                                  'longitude': -80.3849353035918},
#                  'display_phone': '(786) 803-8316',
#                  'distance': 13284.981572499944,
#                  'id': 'fylIHQF8VF2DwLWNUCq3og',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UBtJfIMs1E-j3g0lE9ZHDg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '11790 SW 104th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['11790 SW 104th St',
#                                                   'Miami, FL 33186'],
#                               'state': 'FL',
#                               'zip_code': '33186'},
#                  'name': 'Tacos & Tattoos',
#                  'phone': '+17868038316',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1690,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tacos-and-tattoos-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'}],
#  'region': {'center': {'latitude': 25.752753731496888,
#                        'longitude': -80.2880859375}},
#  'total': 1000}

# %%
#printing top 5 best rated Mexican spots in Miami FL
print('***** 5 best rated Mexican places in Miami,FL *****\n{}\n'.format("yelp_api.search_query(term='mexican', "
                                                                             "location='miami, fl', sort_by='rating', "
                                                                             "limit=5)"))
response = yelp_api.search_query(term='mexican', location='miami, fl', sort_by='rating', limit=5)
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** 5 best rated Mexican places in Miami,FL *****
# yelp_api.search_query(term='mexican', location='miami, fl', sort_by='rating', limit=5)
#
# {'businesses': [{'alias': 'antojitos-mexicanos-tenorio-miami',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.730775,
#                                  'longitude': -80.4153515},
#                  'display_phone': '(305) 225-5125',
#                  'distance': 12979.074151727023,
#                  'id': 'UBWFHeS_Y4VpTWpv49ak7g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/txmuw514Aej7NPrGeYJyzQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4095 SW 137th Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['4095 SW 137th Ave',
#                                                   'Miami, FL 33175'],
#                               'state': 'FL',
#                               'zip_code': '33175'},
#                  'name': 'Antojitos Mexicanos Tenorio',
#                  'phone': '+13052255125',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 262,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/antojitos-mexicanos-tenorio-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'taqueria-viva-méxico-miami-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.7686015253466,
#                                  'longitude': -80.2145662531257},
#                  'display_phone': '(786) 350-6360',
#                  'distance': 7570.501680482599,
#                  'id': '9PEF_qX-3FU4iMmKgk98eA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/25JmaQRZadEc_8STVQEKcA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '502 SW 12th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['502 SW 12th Ave',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Taqueria Viva México',
#                  'phone': '+17863506360',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 416,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/taqueria-viva-m%C3%A9xico-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'a-mari-mix-fresh-mex-fusion-miami',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.7468571893715,
#                                  'longitude': -80.3519500632294},
#                  'display_phone': '(305) 603-9134',
#                  'distance': 6429.709695253538,
#                  'id': 'j0MnMGOdiPscmQ-JIILoag',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mnwz2Mh7j2SpOkABrez52w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9700 SW 24th St',
#                               'address2': 'Ste D',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['9700 SW 24th St',
#                                                   'Ste D',
#                                                   'Miami, FL 33165'],
#                               'state': 'FL',
#                               'zip_code': '33165'},
#                  'name': 'A-Mari-Mix Fresh Mex Fusion',
#                  'phone': '+13056039134',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 223,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/a-mari-mix-fresh-mex-fusion-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'el-donkey-mexican-grill-miami',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 25.701584,
#                                  'longitude': -80.3570983},
#                  'display_phone': '(305) 200-3935',
#                  'distance': 8895.862482317949,
#                  'id': 'nh4td0-yIzXoimKlityncA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mAfQ9Cj2w0-5wagXHucGkA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '10043 SW 72nd St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['10043 SW 72nd St',
#                                                   'Miami, FL 33173'],
#                               'state': 'FL',
#                               'zip_code': '33173'},
#                  'name': 'El Donkey Mexican Grill',
#                  'phone': '+13052003935',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 210,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/el-donkey-mexican-grill-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'tacos-and-tattoos-miami-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'streetvendors',
#                                  'title': 'Street Vendors'}],
#                  'coordinates': {'latitude': 25.6711452954603,
#                                  'longitude': -80.3849353035918},
#                  'display_phone': '(786) 803-8316',
#                  'distance': 13284.981572499944,
#                  'id': 'fylIHQF8VF2DwLWNUCq3og',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UBtJfIMs1E-j3g0lE9ZHDg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '11790 SW 104th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['11790 SW 104th St',
#                                                   'Miami, FL 33186'],
#                               'state': 'FL',
#                               'zip_code': '33186'},
#                  'name': 'Tacos & Tattoos',
#                  'phone': '+17868038316',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1690,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tacos-and-tattoos-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'}],
#  'region': {'center': {'latitude': 25.752753731496888,
#                        'longitude': -80.2880859375}},
#  'total': 1000}
#
# -------------------------------------------------------------------------

# %%
#restaurants supporting delivery
print("***** businesses in Miami supporting delivery transactions *****\n{}\n".format("yelp_api.transaction_search_"
                                                                                       "query(transaction_type="
                                                                                       "'delivery', location='miami, "
                                                                                       "fl')"))
response = yelp_api.transaction_search_query(transaction_type='delivery', location='miami, fl')
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** businesses in Miami supporting delivery transactions *****
# yelp_api.transaction_search_query(transaction_type='delivery', location='miami, fl')
#
# {'businesses': [{'alias': 'mister-o1-brickell-miami',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 25.7643844052975,
#                                  'longitude': -80.1934123866475},
#                  'display_phone': '(786) 332-6868',
#                  'id': 'Tc4YtiYW5z8UcBT8xWsBkQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ocbpjDi_9hP5gcrT-hKdMw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1000 S Miami Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1000 S Miami Ave',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Mister O1 - Brickell',
#                  'phone': '+17863326868',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 455,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/mister-o1-brickell-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': '3-chefs-at-brickell-miami-4',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#                  'coordinates': {'latitude': 25.7624887456795,
#                                  'longitude': -80.1942033298647},
#                  'display_phone': '(305) 377-8338',
#                  'id': 'TiHJpUV56fBSizl73WGY_Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ftl1TXY1DoOBv79w6NXEEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '48 SW 12th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['48 SW 12th St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': "3 Chef's at Brickell",
#                  'phone': '+13053778338',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 178,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/3-chefs-at-brickell-miami-4?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'pine-mediterranean-cuisine-miami',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'lebanese', 'title': 'Lebanese'}],
#                  'coordinates': {'latitude': 25.7738799,
#                                  'longitude': -80.1940599},
#                  'display_phone': '(786) 717-6015',
#                  'id': 'Nuah7ku5B5DbjdT4Y7bTpg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UmlIol5EFUdwuS7qqvzG3Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '16 W Flagler St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['16 W Flagler St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Pine Mediterranean Cuisine',
#                  'phone': '+17867176015',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 59,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/pine-mediterranean-cuisine-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'the-arketekt-by-aficionados-miami-2',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 25.76163, 'longitude': -80.1903},
#                  'display_phone': '(786) 482-6989',
#                  'id': '6fdIvWy8XhmPF66aa9EDRA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GhliuQs-H6nr4kzX_cjbMw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1200 Brickell Bay Dr',
#                               'address2': 'Ste 107',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1200 Brickell Bay Dr',
#                                                   'Ste 107',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'The Arketekt by Aficionados',
#                  'phone': '+17864826989',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 119,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/the-arketekt-by-aficionados-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'salad-box-miami-2',
#                  'categories': [{'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'soup', 'title': 'Soup'}],
#                  'coordinates': {'latitude': 25.7731625,
#                                  'longitude': -80.1887876},
#                  'display_phone': '(786) 901-1398',
#                  'id': 'mLrC1X94UT5HgErB1JHOMA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lmfro4V7arzZhEEWVj-uOw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '125 SE 3rd Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['125 SE 3rd Ave',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Salad Box',
#                  'phone': '+17869011398',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 77,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/salad-box-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'fratelli-milano-miami',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 25.7734433,
#                                  'longitude': -80.1898863},
#                  'display_phone': '(305) 373-2300',
#                  'id': 'C0oehMtQSl_JOKWIX6ORzQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YPF8o3k9OgqdCKoHmq5KPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '213 SE 1st St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['213 SE 1st St',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Fratelli Milano',
#                  'phone': '+13053732300',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1022,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/fratelli-milano-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'doghouse-miami-2',
#                  'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'},
#                                 {'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 25.7643006808455,
#                                  'longitude': -80.1941871643066},
#                  'display_phone': '(305) 381-7770',
#                  'id': 'kDmtuPi7kpSgo-UPT_w_Nw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rRfE14HycFyNPfz1n1KojQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '50 SW 10th St',
#                               'address2': 'Unit 46',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['50 SW 10th St',
#                                                   'Unit 46',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Doghouse',
#                  'phone': '+13053817770',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 189,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/doghouse-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'suviche-brickell-miami',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'peruvian', 'title': 'Peruvian'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 25.763537, 'longitude': -80.1942},
#                  'display_phone': '(305) 960-7097',
#                  'id': 'd3f1luw-fqqzz98fZ0-gSw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jnFFtROlkCpp710EYo0v9Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '49 SW 11th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['49 SW 11th St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'SuViche Brickell',
#                  'phone': '+13059607097',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 420,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/suviche-brickell-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'china-lee-restaurant-miami-3',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.766384,
#                                  'longitude': -80.2036679},
#                  'display_phone': '(305) 856-2801',
#                  'id': 'JACmrsmLZETSI9abfwBP4Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n4D-2HLOvm8Vm_J1NnK0ng/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '559 SW 8th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['559 SW 8th St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'China Lee Restaurant',
#                  'phone': '+13058562801',
#                  'price': '$',
#                  'rating': 3.0,
#                  'review_count': 23,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/china-lee-restaurant-miami-3?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'pizza-onne-miami',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'italian', 'title': 'Italian'}],
#                  'coordinates': {'latitude': 25.7728541,
#                                  'longitude': -80.1919849},
#                  'display_phone': '(305) 372-0508',
#                  'id': 'mLNbmGbfCYcSe4YHRTH9cw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RJg2Hy2RDoZeJARh0EYDCQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '192 SE 1st Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['192 SE 1st Ave',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Pizza Onne',
#                  'phone': '+13053720508',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 16,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/pizza-onne-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'd-oro-caffe-and-market-miami-2',
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'coordinates': {'latitude': 25.7745228,
#                                  'longitude': -80.1884252},
#                  'display_phone': '(305) 371-6300',
#                  'id': 'aJxCpmQotFeRlB7gzZdN4w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6q_2cMWbUBKPW7WQg2CtFw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '17 NE 3rd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['17 NE 3rd Ave',
#                                                   'Miami, FL 33132'],
#                               'state': 'FL',
#                               'zip_code': '33132'},
#                  'name': "D'Oro Caffe & Market",
#                  'phone': '+13053716300',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 85,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/d-oro-caffe-and-market-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': '100-montaditos-miami-7',
#                  'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#                                 {'alias': 'tapas', 'title': 'Tapas Bars'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 25.7600682296887,
#                                  'longitude': -80.1918037460327},
#                  'display_phone': '(786) 409-3107',
#                  'id': 'T5kof6T4QeSekDQxjw68Kg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ca8wH6c4WHd5Q7R5eTNTsw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1401 Brickell Ave',
#                               'address2': 'Ste 130',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1401 Brickell Ave',
#                                                   'Ste 130',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': '100 Montaditos',
#                  'phone': '+17864093107',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 109,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/100-montaditos-miami-7?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'kai-poke-shop-miami',
#                  'categories': [{'alias': 'poke', 'title': 'Poke'},
#                                 {'alias': 'hawaiian', 'title': 'Hawaiian'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 25.7600416574683,
#                                  'longitude': -80.1917876527787},
#                  'display_phone': '(786) 409-3107',
#                  'id': 'FWAxiDIuSOisQdp58ZssbQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_t9gra0k6CVmuiskdO5VFQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1401 Brickell Ave',
#                               'address2': '',
#                               'address3': 'Fourteen Eatery',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['1401 Brickell Ave',
#                                                   'Fourteen Eatery',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Kai Poke Shop',
#                  'phone': '+17864093107',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 48,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/kai-poke-shop-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'cabanas-restaurant-miami',
#                  'categories': [{'alias': 'latin', 'title': 'Latin American'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 25.7662986,
#                                  'longitude': -80.201358},
#                  'display_phone': '(305) 856-8488',
#                  'id': 'AbGPw7KTGbzkYmjqfvK0yw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jP2P-DE-KO8XRGgZDfjtag/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '435 SW 8th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['435 SW 8th St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Cabanas Restaurant',
#                  'phone': '+13058568488',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 80,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/cabanas-restaurant-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'tacos-frida-luna-mexican-grill-miami',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'tacos', 'title': 'Tacos'}],
#                  'coordinates': {'latitude': 25.7666, 'longitude': -80.19791},
#                  'display_phone': '',
#                  'id': 'quf6OjPAeYtp_8bF7JTAQw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yv6GtxpK3fdCKVJE4k-EJQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '229 SW 8th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['229 SW 8th St',
#                                                   'Miami, FL 33130'],
#                               'state': 'FL',
#                               'zip_code': '33130'},
#                  'name': 'Tacos Frida Luna Mexican Grill',
#                  'phone': '',
#                  'rating': 3.0,
#                  'review_count': 9,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/tacos-frida-luna-mexican-grill-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'pizza-rustica-miami-2',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 25.76832, 'longitude': -80.19079},
#                  'display_phone': '(786) 787-8422',
#                  'id': 'YrU0v2T7kqH3FKYjAdvZlg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/aRiSAQkw9zzgGam2-Wc39g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '500 Brickell Ave',
#                               'address2': '102W',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['500 Brickell Ave',
#                                                   '102W',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Pizza Rustica',
#                  'phone': '+17867878422',
#                  'price': '$',
#                  'rating': 3.0,
#                  'review_count': 141,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/pizza-rustica-miami-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'first-hong-kong-cafe-miami',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 25.7727393818968,
#                                  'longitude': -80.1908402252383},
#                  'display_phone': '(305) 808-6665',
#                  'id': 'nTldK01X5GMVPnvdnIM9Gw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PxNf9UFdNnb2uuJiorGtaw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '117 SE 2nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['117 SE 2nd St',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'First Hong Kong Cafe',
#                  'phone': '+13058086665',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 112,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/first-hong-kong-cafe-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'lees-sushi-miami',
#                  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#                                 {'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 25.77376, 'longitude': -80.19243},
#                  'display_phone': '(305) 316-4070',
#                  'id': 'oaX8uygM_AjihZavNIb-wQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gH9zjSXZObD_DQl6bnQt6Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '48 E Flagler',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['48 E Flagler',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': "Lee's Sushi",
#                  'phone': '+13053164070',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 49,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/lees-sushi-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'station-28-miami-3',
#                  'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'peruvian', 'title': 'Peruvian'},
#                                 {'alias': 'sportsbars',
#                                  'title': 'Sports Bars'}],
#                  'coordinates': {'latitude': 25.7728914339146,
#                                  'longitude': -80.1921365315806},
#                  'display_phone': '(305) 905-0328',
#                  'id': 'b8_XgMhKSPl__dRgY-m6Ig',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LamzWibBf0VNrnp4fN-Qtg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '91 SE 2nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['91 SE 2nd St',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Station 28',
#                  'phone': '+13059050328',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 152,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/station-28-miami-3?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'okinawa-sushi-express-miami',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 25.773162,
#                                  'longitude': -80.1900651},
#                  'display_phone': '(305) 381-8688',
#                  'id': 'i3TO3sOI2HzIje0SfnUX2w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-KoX4J3SWDd5pRh611EjDg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '119 SE 2nd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Miami',
#                               'country': 'US',
#                               'display_address': ['119 SE 2nd Ave',
#                                                   'Miami, FL 33131'],
#                               'state': 'FL',
#                               'zip_code': '33131'},
#                  'name': 'Okinawa Sushi Express',
#                  'phone': '+13053818688',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 99,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/okinawa-sushi-express-miami?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'}],
#  'total': 47}
#
# -------------------------------------------------------------------------
#
# 0
