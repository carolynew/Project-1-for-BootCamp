# %%
import csv
import matplotlib.pyplot as plt 
import requests
import json
import pandas as pd 
from config import api_key
from yelpapi import YelpAPI
import argparse

from pprint import pprint

argparser = argparse.ArgumentParser(description='Example Yelp queries using yelpapi. Visit https://www.yelp.com/developers/v3/manage_app to get the necessary API keys.')
argparser.add_argument(api_key, type=str, help='Yelp Fusion API Key')
# Out:
# _StoreAction(option_strings=[], dest='VpAqdsRiA4HvlGHzH0toLKhZZSQL2An4bkyl1sK6g2Hn-KScAF1xxAKb3wkFfxrioeKYvFRY5RtMBeEt3hngOhFIQTvPOgzrotLLzkAGAk6X3GtlVSxIL31Ov5NmXXYx', nargs=None, const=None, default=None, type=<class 'str'>, choices=None, help='Yelp Fusion API Key', metavar=None)

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for Inexpensive Restaurants ($)
search_1_results = yelp_api.search_query(term='restaurants', location='los angeles, ca', price=1)
pprint (search_1_results['total'])

#search yelp library for Less Expensive Restaurants ($$)
search_2_results = yelp_api.search_query(term='restaurants', location='los angeles, ca', price=2)
pprint (search_2_results['total'])

#search yelp library for More Expensive Restaurants ($$$)
search_3_results = yelp_api.search_query(term='restaurants', location='los angeles, ca', price=3)
pprint (search_3_results['total'])

#search yelp library for Expensive Restaurants ($$$$)
search_4_results = yelp_api.search_query(term='restaurants', location='los angeles, ca', price=4)
pprint (search_4_results['total'])
# Out:
# 3200
# 3200
# 289
# 77

# %%
#printing top 5 best rated Mexican spots in LA
print('***** 5 best rated Mexican places in Los Angeles, CA *****\n{}\n'.format("yelp_api.search_query(term='mexican', "
                                                                             "location='los angeles, ca', sort_by='rating', "
                                                                             "limit=5)"))
response = yelp_api.search_query(term='mexican', location='los angeles, ca', sort_by='rating', limit=5)
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** 5 best rated Mexican places in Los Angeles, CA *****
# yelp_api.search_query(term='mexican', location='los angeles, ca', sort_by='rating', limit=5)
#
# {'businesses': [{'alias': 'tlayuda-la-restaurant-los-angeles',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'latin', 'title': 'Latin American'}],
#                  'coordinates': {'latitude': 34.0906351,
#                                  'longitude': -118.307928},
#                  'display_phone': '(213) 261-4667',
#                  'distance': 3458.2073511243375,
#                  'id': 'Lop79P2KM9zFUCCaBYz6zA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EGu5l3ycoQ52i8FW6iSHXQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5450 Santa Monica Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['5450 Santa Monica Blvd',
#                                                   'Los Angeles, CA 90029'],
#                               'state': 'CA',
#                               'zip_code': '90029'},
#                  'name': 'Tlayuda La Restaurant',
#                  'phone': '+12132614667',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 683,
#                  'transactions': ['pickup'],
#                  'url': 'https://www.yelp.com/biz/tlayuda-la-restaurant-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'quiadaiyn-restaurant-los-angeles',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 34.003606,
#                                  'longitude': -118.4329843},
#                  'display_phone': '(310) 313-7654',
#                  'distance': 12138.145326838963,
#                  'id': '6ZUvXgNrDiJ5vHDRXdshpA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QCouQrWzlzEn2s3EoZ53uA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '12326 Venice Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['12326 Venice Blvd',
#                                                   'Los Angeles, CA 90066'],
#                               'state': 'CA',
#                               'zip_code': '90066'},
#                  'name': 'Quiadaiyn Restaurant',
#                  'phone': '+13103137654',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 124,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/quiadaiyn-restaurant-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'bennys-tacos-and-chicken-rotisserie-los-angeles-4',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#                  'coordinates': {'latitude': 33.95998, 'longitude': -118.41685},
#                  'display_phone': '(310) 670-8226',
#                  'distance': 14320.8826728025,
#                  'id': 'uA3TautyZ7bby0w8Scwufg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DvYYgTEklvMM_HMhbMX1rA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7101 W Manchester Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['7101 W Manchester Ave',
#                                                   'Los Angeles, CA 90045'],
#                               'state': 'CA',
#                               'zip_code': '90045'},
#                  'name': "Benny's Tacos & Chicken Rotisserie",
#                  'phone': '+13106708226',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1882,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/bennys-tacos-and-chicken-rotisserie-los-angeles-4?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'la-azteca-tortilleria-los-angeles',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 34.04031, 'longitude': -118.16796},
#                  'display_phone': '(323) 262-5977',
#                  'distance': 14324.832971109487,
#                  'id': 'WGs6gf1ULVPkr-0AsRVsRA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HGyP2l0Iv1rEDIZU5xDPeg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4538 E Cesar E Chavez Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['4538 E Cesar E Chavez Ave',
#                                                   'Los Angeles, CA 90022'],
#                               'state': 'CA',
#                               'zip_code': '90022'},
#                  'name': 'La Azteca Tortilleria',
#                  'phone': '+13232625977',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1090,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/la-azteca-tortilleria-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'taqueria-los-anaya-los-angeles',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 34.0327911,
#                                  'longitude': -118.3417282},
#                  'display_phone': '(323) 731-4070',
#                  'distance': 3720.848506858027,
#                  'id': '6Dd4kTDiikEB3wQp___0fA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/T6KacOTiaa2TudDlU2lykQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4651 W Adams Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['4651 W Adams Blvd',
#                                                   'Los Angeles, CA 90016'],
#                               'state': 'CA',
#                               'zip_code': '90016'},
#                  'name': 'Taqueria Los Anaya',
#                  'phone': '+13237314070',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1120,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/taqueria-los-anaya-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VeuwCtfmB4VyXWuUYbZp8w'}],
#  'region': {'center': {'latitude': 34.0615895441259,
#                        'longitude': -118.32138061523438}},
#  'total': 8600}
#
# -------------------------------------------------------------------------

# %%
#restaurants supporting delivery
print("***** businesses in LA supporting delivery transactions *****\n{}\n".format("yelp_api.transaction_search_"
                                                                                       "query(transaction_type="
                                                                                       "'delivery', location='los angeles, ca')"))
response = yelp_api.transaction_search_query(transaction_type='delivery', location='los angeles, ca')
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** businesses in LA supporting delivery transactions *****
# yelp_api.transaction_search_query(transaction_type='delivery', location='los angeles, ca')
#
# {'businesses': [{'alias': 'wendys-tortas-los-angeles-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 34.0661149,
#                                  'longitude': -118.21526},
#                  'display_phone': '(323) 224-1619',
#                  'id': 'xtkb1BbZlxtU2cRChARLxA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7FAlNX2k5YLT-u_j0lgnaQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2603 N Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['2603 N Main St',
#                                                   'Los Angeles, CA 90031'],
#                               'state': 'CA',
#                               'zip_code': '90031'},
#                  'name': "Wendy's Tortas",
#                  'phone': '+13232241619',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 205,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/wendys-tortas-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'bbq-chicken-los-angeles-8',
#                  'categories': [{'alias': 'korean', 'title': 'Korean'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'chickenshop',
#                                  'title': 'Chicken Shop'}],
#                  'coordinates': {'latitude': 34.0471568958382,
#                                  'longitude': -118.238785341382},
#                  'display_phone': '(323) 989-9000',
#                  'id': 'A0Ywsdx5X6g8icczpAayhQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wyA9J4t9JEf--VKj3bxYMA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '442 E 2nd St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['442 E 2nd St',
#                                                   'Los Angeles, CA 90012'],
#                               'state': 'CA',
#                               'zip_code': '90012'},
#                  'name': 'BBQ Chicken',
#                  'phone': '+13239899000',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 180,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bbq-chicken-los-angeles-8?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'orleans-and-york-deli-los-angeles-3',
#                  'categories': [{'alias': 'delis', 'title': 'Delis'}],
#                  'coordinates': {'latitude': 34.0495262,
#                                  'longitude': -118.2478561},
#                  'display_phone': '(213) 687-0400',
#                  'id': 'iWS7Olqaw4hyWvMLIwJ9mw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/khD01wi1SgJA-6hAQMzWPA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '333 S Spring St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['333 S Spring St',
#                                                   'Los Angeles, CA 90013'],
#                               'state': 'CA',
#                               'zip_code': '90013'},
#                  'name': 'Orleans & York Deli',
#                  'phone': '+12136870400',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 316,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/orleans-and-york-deli-los-angeles-3?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'sabores-del-perú-los-angeles',
#                  'categories': [{'alias': 'peruvian', 'title': 'Peruvian'}],
#                  'coordinates': {'latitude': 34.03735, 'longitude': -118.25383},
#                  'display_phone': '(213) 749-2174',
#                  'id': 'ZMNTxFRHewwBgiAh58Z25w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qB_SX5_lsrmgjR9x5fM7wQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '455 E Olympic Blvd',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['455 E Olympic Blvd',
#                                                   'Los Angeles, CA 90015'],
#                               'state': 'CA',
#                               'zip_code': '90015'},
#                  'name': 'Sabores Del Perú',
#                  'phone': '+12137492174',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 42,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/sabores-del-per%C3%BA-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'market-place-restaurant-los-angeles',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 34.03039, 'longitude': -118.23652},
#                  'display_phone': '(213) 622-7285',
#                  'id': 'fEZN5WiAu-bO2KnPCxLR5A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KMJ0x0nxo7NMmcOvMcKU8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1102 Lawrence St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['1102 Lawrence St',
#                                                   'Los Angeles, CA 90021'],
#                               'state': 'CA',
#                               'zip_code': '90021'},
#                  'name': 'Market Place Restaurant',
#                  'phone': '+12136227285',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 123,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/market-place-restaurant-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'press-brothers-juicery-los-angeles-2',
#                  'categories': [{'alias': 'juicebars',
#                                  'title': 'Juice Bars & Smoothies'}],
#                  'coordinates': {'latitude': 34.0505788,
#                                  'longitude': -118.2486735},
#                  'display_phone': '(213) 389-3645',
#                  'id': '-cvt3Je4hbpVKhJf1YcblQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FT_TFP5JH55HKul05IpBrQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '317 S Broadway',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['317 S Broadway',
#                                                   'Los Angeles, CA 90013'],
#                               'state': 'CA',
#                               'zip_code': '90013'},
#                  'name': 'Press Brothers Juicery',
#                  'phone': '+12133893645',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 186,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/press-brothers-juicery-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'kabab-and-more-los-angeles-2',
#                  'categories': [{'alias': 'persian',
#                                  'title': 'Persian/Iranian'},
#                                 {'alias': 'mideastern',
#                                  'title': 'Middle Eastern'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'}],
#                  'coordinates': {'latitude': 34.0463373,
#                                  'longitude': -118.2542688},
#                  'display_phone': '(213) 621-0443',
#                  'id': 'JxUG-uHor8dwUGNfvW5MaQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IkQRSf6kNtZB0fH24qzdoQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '663 S Hill St',
#                               'address2': 'Ste M105',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['663 S Hill St',
#                                                   'Ste M105',
#                                                   'Los Angeles, CA 90014'],
#                               'state': 'CA',
#                               'zip_code': '90014'},
#                  'name': 'Kabab & More',
#                  'phone': '+12136210443',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 117,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/kabab-and-more-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'the-new-moon-los-angeles',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#                  'coordinates': {'latitude': 34.0415537,
#                                  'longitude': -118.255232},
#                  'display_phone': '(213) 624-0186',
#                  'id': '5WRkjiZWv25aGOUqfupSUQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/pa3uu72jlg6CyWLDvBJEHQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '102 W 9th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['102 W 9th St',
#                                                   'Los Angeles, CA 90015'],
#                               'state': 'CA',
#                               'zip_code': '90015'},
#                  'name': 'The New Moon',
#                  'phone': '+12136240186',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 257,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/the-new-moon-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': '464-los-angeles-2',
#                  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'beerbar', 'title': 'Beer Bar'}],
#                  'coordinates': {'latitude': 34.0467173386993,
#                                  'longitude': -118.248295286018},
#                  'display_phone': '(213) 884-0181',
#                  'id': '5hEf8nOB2O9w-Uvo52CzhQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9h7HknwjVqGMzDIxAgl5AA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '464 S Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['464 S Main St',
#                                                   'Los Angeles, CA 90013'],
#                               'state': 'CA',
#                               'zip_code': '90013'},
#                  'name': '464',
#                  'phone': '+12138840181',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 359,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/464-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'sevan-garden-kebab-house-los-angeles',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'turkish', 'title': 'Turkish'},
#                                 {'alias': 'armenian', 'title': 'Armenian'}],
#                  'coordinates': {'latitude': 34.046256,
#                                  'longitude': -118.252875},
#                  'display_phone': '(213) 489-5626',
#                  'id': 'JbIuJKkmv2SUkzZnbixFQQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/oyIsDyrzMNv0pHzA7NcZ8A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '621 S Broadway',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['621 S Broadway',
#                                                   'Los Angeles, CA 90014'],
#                               'state': 'CA',
#                               'zip_code': '90014'},
#                  'name': 'Sevan Garden Kebab House',
#                  'phone': '+12134895626',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 138,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/sevan-garden-kebab-house-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'california-kabob-kitchen-los-angeles',
#                  'categories': [{'alias': 'mideastern',
#                                  'title': 'Middle Eastern'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'persian',
#                                  'title': 'Persian/Iranian'}],
#                  'coordinates': {'latitude': 34.03999, 'longitude': -118.25899},
#                  'display_phone': '(213) 747-9500',
#                  'id': 'Z6_Gitnw1JV-KIJYioFtHA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7tuSd3Edl3vUTwzTumx76w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '141 W 11th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['141 W 11th St',
#                                                   'Los Angeles, CA 90015'],
#                               'state': 'CA',
#                               'zip_code': '90015'},
#                  'name': 'California Kabob Kitchen',
#                  'phone': '+12137479500',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 211,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/california-kabob-kitchen-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'spring-street-smoke-house-los-angeles-2',
#                  'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#                                 {'alias': 'southern', 'title': 'Southern'}],
#                  'coordinates': {'latitude': 34.0584418,
#                                  'longitude': -118.2384744},
#                  'display_phone': '(213) 626-0535',
#                  'id': 'NiqUaspI5PMx8tTGc2m9Rg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mfiPAK8XJMhbrGvdVPWV8w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '640 N Spring St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['640 N Spring St',
#                                                   'Los Angeles, CA 90012'],
#                               'state': 'CA',
#                               'zip_code': '90012'},
#                  'name': 'Spring Street Smoke House',
#                  'phone': '+12136260535',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 987,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/spring-street-smoke-house-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'braazo-pizza-los-angeles',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'salad', 'title': 'Salad'},
#                                 {'alias': 'bbq', 'title': 'Barbeque'}],
#                  'coordinates': {'latitude': 34.0438886,
#                                  'longitude': -118.251571},
#                  'display_phone': '(213) 622-3390',
#                  'id': 'T1RfgUMYKW3HD55SEJILbQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/h23pKAd393nUnSc2PSAOfw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 1/2 W 7th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['100 1/2 W 7th St',
#                                                   'Los Angeles, CA 90014'],
#                               'state': 'CA',
#                               'zip_code': '90014'},
#                  'name': 'Braazo Pizza',
#                  'phone': '+12136223390',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 469,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/braazo-pizza-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'papa-johns-pizza-los-angeles-15',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 34.0612326138807,
#                                  'longitude': -118.244308904917},
#                  'display_phone': '(213) 617-2727',
#                  'id': 'nh2N06eY7k2l5r6KtxUYVg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VX8wM6DcrWfeFj9nJhYfTA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '701 W Cesar E Chavez Ave',
#                               'address2': 'Ste 109',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['701 W Cesar E Chavez Ave',
#                                                   'Ste 109',
#                                                   'Los Angeles, CA 90012'],
#                               'state': 'CA',
#                               'zip_code': '90012'},
#                  'name': "Papa John's Pizza",
#                  'phone': '+12136172727',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 75,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/papa-johns-pizza-los-angeles-15?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'ocho-mexican-grill-los-angeles',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 34.0491019658059,
#                                  'longitude': -118.25615349259},
#                  'display_phone': '(213) 788-4788',
#                  'id': 'h5g2SpBkhVneJsNwZ-se4A',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WIzR5Yr_idmwQqTrd7IbNQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '630 W 6th St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['630 W 6th St',
#                                                   'Los Angeles, CA 90017'],
#                               'state': 'CA',
#                               'zip_code': '90017'},
#                  'name': 'Ocho Mexican Grill',
#                  'phone': '+12137884788',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 281,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/ocho-mexican-grill-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'gelateria-uli-los-angeles',
#                  'categories': [{'alias': 'icecream',
#                                  'title': 'Ice Cream & Frozen Yogurt'},
#                                 {'alias': 'gelato', 'title': 'Gelato'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 34.0466413015739,
#                                  'longitude': -118.250713186508},
#                  'display_phone': '(213) 537-0931',
#                  'id': '6QBrXAfQ9U-DbNf6rAlNIg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zbEINV6HOOxdlAUgQsjAvA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '541 S Spring St',
#                               'address2': 'Ste 104',
#                               'address3': 'Spring Arcade Building',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['541 S Spring St',
#                                                   'Ste 104',
#                                                   'Spring Arcade Building',
#                                                   'Los Angeles, CA 90013'],
#                               'state': 'CA',
#                               'zip_code': '90013'},
#                  'name': 'Gelateria Uli',
#                  'phone': '+12135370931',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 636,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/gelateria-uli-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'ocho-mexican-grill-los-angeles-2',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 34.0533172115148,
#                                  'longitude': -118.251294493675},
#                  'display_phone': '(213) 788-4888',
#                  'id': '4Ko9u0y30qU-c-IUbxU7eQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/njeQK1VOPyjm5TXdVcDIPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '255 S Grand Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['255 S Grand Ave',
#                                                   'Los Angeles, CA 90012'],
#                               'state': 'CA',
#                               'zip_code': '90012'},
#                  'name': 'Ocho Mexican Grill',
#                  'phone': '+12137884888',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 223,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/ocho-mexican-grill-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'bangkok-palace-los-angeles',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 34.0777913739074,
#                                  'longitude': -118.266602994823},
#                  'display_phone': '(213) 483-6913',
#                  'id': 'GJLJ368dETITnVruS9Lo2g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PNBmpy73nSCGjiZMXmwaug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2202 W Sunset Blvd',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['2202 W Sunset Blvd',
#                                                   'Los Angeles, CA 90026'],
#                               'state': 'CA',
#                               'zip_code': '90026'},
#                  'name': 'Bangkok Palace',
#                  'phone': '+12134836913',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 227,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/bangkok-palace-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'purgatory-pizza-los-angeles-2',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'vegan', 'title': 'Vegan'},
#                                 {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#                  'coordinates': {'latitude': 34.0475041,
#                                  'longitude': -118.2254502},
#                  'display_phone': '(323) 262-5310',
#                  'id': 'zDQm3hXszZOov-w6IAI31A',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CGJtOL-Y7eK_T31DyrGjhg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1326 E 1st St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['1326 E 1st St',
#                                                   'Los Angeles, CA 90033'],
#                               'state': 'CA',
#                               'zip_code': '90033'},
#                  'name': 'Purgatory Pizza',
#                  'phone': '+13232625310',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 759,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/purgatory-pizza-los-angeles-2?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'},
#                 {'alias': 'blosom-bento-los-angeles',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#                                 {'alias': 'sushi', 'title': 'Sushi Bars'}],
#                  'coordinates': {'latitude': 34.033363,
#                                  'longitude': -118.252109},
#                  'display_phone': '(213) 746-4642',
#                  'id': '9LhTwooIek16VpnPY2olSw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KSOfSuirg5FfuNo6WTgZYw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '735 E 12th St',
#                               'address2': 'Ste 411',
#                               'address3': '',
#                               'city': 'Los Angeles',
#                               'country': 'US',
#                               'display_address': ['735 E 12th St',
#                                                   'Ste 411',
#                                                   'Los Angeles, CA 90021'],
#                               'state': 'CA',
#                               'zip_code': '90021'},
#                  'name': 'Blosom Bento',
#                  'phone': '+12137464642',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 46,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/blosom-bento-los-angeles?adjust_creative=VeuwCtfmB4VyXWuUYbZp8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_transactions_search_delivery&utm_source=VeuwCtfmB4VyXWuUYbZp8w'}],
#  'total': 44}
#
# -------------------------------------------------------------------------

# %%
cities = []
api_key = api_key

# start url
url = "https://api.yelp.com/v3/businesses/" + api_key

# create lists to append the data to
name = []
price = []
rating = []

# Start the call counter 
record = 1

# print
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities
for restaurant in cities:  
    
    try: 
        response = requests.get(f"{url}&q={restaurant}").json() 
        name.append(response["name"])
        price.append(response["price"])
        rating.append(response["rating"])
        
        restaurant_record = response["name"]
        
        print(f"Processing Record {record} | {restaurant_record}")
        print(f"{restaurant}")
        
        # Increase counter by one 
        record= record + 1

        
    # skip if you cant find the city
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------

# %%
la_dict = {
    "Restaurant": name,
    "Price":price, 
    "Rating":rating
}

# Create a data frame from the dictionary you created above
la_data = pd.DataFrame(la_dict)

# Display the count
la_data.count()
# Out:
# Restaurant    0
# Price         0
# Rating        0
# dtype: int64

# %%
print(url)
# Out:
# https://api.yelp.com/v3/businesses/VpAqdsRiA4HvlGHzH0toLKhZZSQL2An4bkyl1sK6g2Hn-KScAF1xxAKb3wkFfxrioeKYvFRY5RtMBeEt3hngOhFIQTvPOgzrotLLzkAGAk6X3GtlVSxIL31Ov5NmXXYx
