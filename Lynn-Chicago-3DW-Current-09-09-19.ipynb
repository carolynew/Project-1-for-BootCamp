# %%
import csv
import matplotlib.pyplot as plt 
import requests
import json
import pandas as pd 
from config import api_key
from yelpapi import YelpAPI
import argparse

from pprint import pprint

argparser = argparse.ArgumentParser(description='Example Yelp queries using yelpapi. Visit https://www.yelp.com/developers/v3/manage_app to get the necessary API keys.')
argparser.add_argument(api_key, type=str, help='Yelp Fusion API Key')
# Out:
# _StoreAction(option_strings=[], dest='t9Aqpq086bS4P_h7RY-fgMeMbrrKr-D_cdrrllrO8gCuPPyY3K7V6ELW_OFMKvoI3wa4jlx0ahhlESLkb4YQsTmiWMtiZhWlwu9eMhtKWZL5OrtqRmUBu2IAQa9pXXYx', nargs=None, const=None, default=None, type=<class 'str'>, choices=None, help='Yelp Fusion API Key', metavar=None)

# %%
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for "Pizza restaurants"

search_results = yelp_api.search_query(term='pizza', location='chicago, il', sort_by='rating', limit=50)
pprint (search_results)
# Out:
# {'businesses': [{'alias': 'bobs-pizza-chicago',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#                  'coordinates': {'latitude': 41.853945,
#                                  'longitude': -87.6683543622494},
#                  'display_phone': '(312) 600-6155',
#                  'distance': 5747.806191846369,
#                  'id': '1wSxClt75nOBS31--dlWYg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NtA_-fyc9l991m2TNvMcnA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1659 W 21st St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Chicago',
#                               'country': 'US',
#                               'display_address': ['1659 W 21st St',
#                                                   'Chicago, IL 60608'],
#                               'state': 'IL',
# ...

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for "Puerto Rican restaurants"

search_results = yelp_api.search_query(term='puerto_rican', location='chicago, il', sort_by='rating', limit=50)
pprint (search_results)
# Out:
# {'businesses': [{'alias': 'ninis-deli-chicago',
#                  'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#                                 {'alias': 'empanadas', 'title': 'Empanadas'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 41.89235, 'longitude': -87.66198},
#                  'display_phone': '(312) 243-9822',
#                  'distance': 1930.804400581344,
#                  'id': 'F2NBch93KPaQdM_x0Fs2VQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Rep6irkZ1DHGdx58OX9vw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '543 N Noble St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Chicago',
#                               'country': 'US',
# ...

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for "Ribs restaurants"

search_results = yelp_api.search_query(term='ribs', location='chicago, il', sort_by='rating', limit=50)
pprint (search_results)
# Out:
# {'businesses': [{'alias': 'mother-cluckers-kitchen-chicago',
#                  'categories': [{'alias': 'southern', 'title': 'Southern'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 41.9752685744915,
#                                  'longitude': -87.7522482539673},
#                  'display_phone': '(773) 685-4630',
#                  'distance': 9936.179426962337,
#                  'id': 'e9aAISx0navH8qMr33X4TA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BSCoicT4u1mtGYBoBMz3Rw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5200 N Elston Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Chicago',
#                               'country': 'US',
# ...

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for "Pizza restaurants"


search_results = yelp_api.search_query(term='pizza', location='chicago, il', sort_by='rating', limit=50)
#pprint (search_results)
df = pd.DataFrame(search_results['businesses'])
df.to_csv('chicago_Pizza_Restaurants.csv')
df.head()
# Out:
#                                           alias  \
# 0                            bobs-pizza-chicago
# 1          stix-n-brix-wood-fired-pizza-chicago
# 2       forno-rosso-pizzeria-napoletana-chicago
# 3          anto-pizza-and-pasta-chicago-chicago
# 4  la-crosta-woodfire-pizzeria-italiana-chicago
#
#                                           categories  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 2  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 3         [{'alias': 'italian', 'title': 'Italian'}]
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 41.853945, 'longitude': -87.66835...  (312) 600-6155
# 1  {'latitude': 41.8347077589943, 'longitude': -8...  (312) 265-0219
# 2     {'latitude': 41.94767, 'longitude': -87.80672}  (773) 716-3000
# 3     {'latitude': 42.01578, 'longitude': -87.66985}  (773) 942-7427
# ...

# %%
# Delete extraneous columns
del df['categories']
df.head()
# Out:
#                                           alias  \
# 0                            bobs-pizza-chicago
# 1          stix-n-brix-wood-fired-pizza-chicago
# 2       forno-rosso-pizzeria-napoletana-chicago
# 3          anto-pizza-and-pasta-chicago-chicago
# 4  la-crosta-woodfire-pizzeria-italiana-chicago
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 41.853945, 'longitude': -87.66835...  (312) 600-6155
# 1  {'latitude': 41.8347077589943, 'longitude': -8...  (312) 265-0219
# 2     {'latitude': 41.94767, 'longitude': -87.80672}  (773) 716-3000
# 3     {'latitude': 42.01578, 'longitude': -87.66985}  (773) 942-7427
# 4  {'latitude': 41.9248027560034, 'longitude': -8...  (773) 649-1000
#
#        distance                      id  \
# 0   5747.806192  1wSxClt75nOBS31--dlWYg
# 1   8689.035357  zGd8pahz1B1AyShe1t-lvQ
# 2  11670.194132  6EiFN9NS9BQnqw8FXWiY4A
# 3  12323.229697  ss_w9TZiXBnuBrTfrMtG4Q
# 4   3278.223792  Z-SJv3keY-u2bIAnkrDq_Q
#
# ...

# %%
print('***** 5 best rated Pizza places in Chicago, IL *****\n')
response = yelp_api.search_query(term='pizza', location='chicago, il', limit=5, sort_by='review_count')
#pprint(response)
print('\n-------------------------------------------------------------------------\n')

pd.DataFrame(response['businesses'])
df.head()
# Out:
# ***** 5 best rated Pizza places in Chicago, IL *****
#
#
# -------------------------------------------------------------------------
#                                           alias  \
# 0                            bobs-pizza-chicago
# 1          stix-n-brix-wood-fired-pizza-chicago
# 2       forno-rosso-pizzeria-napoletana-chicago
# 3          anto-pizza-and-pasta-chicago-chicago
# 4  la-crosta-woodfire-pizzeria-italiana-chicago
#
#                                           categories  \
# 0             [{'alias': 'pizza', 'title': 'Pizza'}]
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 2  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 3         [{'alias': 'italian', 'title': 'Italian'}]
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 41.853945, 'longitude': -87.66835...  (312) 600-6155
# 1  {'latitude': 41.8347077589943, 'longitude': -8...  (312) 265-0219
# ...

# %%
print('***** 5 best rated places in Chicago, IL by Review Count*****\n')
response = yelp_api.search_query(term='pizza', location='chicago, il', limit=5, sort_by='review_count')
#pprint(response)

ribs_data = yelp_api.search_query(term='ribs', location='chicago, il', attributes='restaurant')
puerto_rican_data = yelp_api.search_query(term='puerto_rican', location='chicago, il', attributes='restaurant')
pizza_data = yelp_api.search_query(term='pizza', location='chicago, il', attributes='restaurant')
italian_data = yelp_api.search_query(term='italian', location='chicago, il', attributes='restaurant')
greek_data = yelp_api.search_query(term='greek', location='chicago, il', attributes='restaurant')
steakhouses_data = yelp_api.search_query(term='steakhouses', location='chicago, il', attributes='restaurant')
hot_dogs_data = yelp_api.search_query(term='chinese', location='chicago, il', attributes='restaurant')

print(ribs_data['total'])
print(puerto_rican_data['total'])
print(pizza_data['total'])
print(italian_data['total'])
print(greek_data['total'])
print(steakhouses_data['total'])
print(hot_dogs_data['total'])
# Out:
# ***** 5 best rated places in Chicago, IL by Review Count*****
#
# 3600
# 115
# 4400
# 3000
# 525
# 822
# 1100

# %%
chicago_dict = {
    "Ribs":ribs_data,
    "Puerto_Rican":puerto_rican_data,
    "Pizza":pizza_data,
    "Italian":italian_data, 
    "Greek":greek_data,
    "Steakhouses":steakhouses_data, 
    "Hot Dogs": hot_dogs_data,
}

# Create a data frame from the dictionary you created above
chicago_data = pd.DataFrame(chicago_dict)

# Display the count
chicago_data.head()
# Out:
#                                                          Ribs  \
# businesses  [{'id': 'LPwAwxEjetjdNh7Uadro3g', 'alias': 'sm...
# region      {'center': {'longitude': -87.67776489257812, '...
# total                                                    3600
#
#                                                  Puerto_Rican  \
# businesses  [{'id': 'nRnrKX7vMf71BknQdCM-cQ', 'alias': 'co...
# region      {'center': {'longitude': -87.67776489257812, '...
# total                                                     115
#
#                                                         Pizza  \
# businesses  [{'id': 'DXwSYgiXqIVNdO9dazel6w', 'alias': 'pe...
# region      {'center': {'longitude': -87.67776489257812, '...
# total                                                    4400
#
#                                                       Italian  \
# businesses  [{'id': 'LYppbvgJlBG0SqjSKFiFGg', 'alias': 'sa...
# region      {'center': {'longitude': -87.67776489257812, '...
# ...

# %%
chicago_data.drop(['businesses','region'], inplace=True)
chicago_data
# Out:
#        Ribs Puerto_Rican Pizza Italian Greek Steakhouses Hot Dogs
# total  3600          115  4400    3000   525         822     1100

# %%
print('***** 5 best rated Steakhouses places in Chicago, IL *****\n')
response = yelp_api.search_query(term='steakhouses', location='chicago, il', limit=5, sort_by='review_count')
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** 5 best rated Steakhouses places in Chicago, IL *****
#
# {'businesses': [{'alias': 'girl-and-the-goat-chicago',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 41.884176,
#                                  'longitude': -87.6479440725005},
#                  'display_phone': '(312) 492-6262',
#                  'distance': 3396.525042772812,
#                  'id': 'qjnpkS8yZO8xcyEIy5OU9A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ya6gjD4BPlxe7AKMj_5WsA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '809 W Randolph St',
#                               'address2': '',
#                               'address3': '',
# ...

# %%
print('***** 5 best rated Hot Dog places in Chicago, IL *****\n')
response = yelp_api.search_query(term='hot_dog', location='chicago, il', limit=5, sort_by='review_count')
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** 5 best rated Hot Dog places in Chicago, IL *****
#
# {'businesses': [{'alias': 'hot-g-dog-chicago',
#                  'categories': [{'alias': 'hotdog', 'title': 'Hot Dogs'}],
#                  'coordinates': {'latitude': 41.9728775,
#                                  'longitude': -87.6677933},
#                  'display_phone': '(773) 209-3360',
#                  'distance': 7569.861921418694,
#                  'id': 'oQX8MSjF2j3pWW7AfWl4eA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/57eXED0PtXADzRTwrW_nvA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5009 N Clark St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Chicago',
#                               'country': 'US',
#                               'display_address': ['5009 N Clark St',
# ...

# %%
print('***** 5 best rated Greek places in Chicago, IL *****\n')
response = yelp_api.search_query(term='greek', location='chicago, il', limit=5, sort_by='review_count')
pprint(response)
print('\n-------------------------------------------------------------------------\n')
# Out:
# ***** 5 best rated Greek places in Chicago, IL *****
#
# {'businesses': [{'alias': 'the-purple-pig-chicago',
#                  'categories': [{'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 41.890694,
#                                  'longitude': -87.624782},
#                  'display_phone': '(312) 464-1744',
#                  'distance': 4670.876906589787,
#                  'id': 'boE4Ahsssqic7o5wQLI04w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qf9YAh6piSujT5F1T6PALg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '444 N Michigan Ave',
# ...

# %%
yelp_api = YelpAPI(api_key)
#search yelp library for Inexpensive Restaurants ($)
search_1_results = yelp_api.search_query(term='restaurants', location='chicago, il', price=1)
pprint (search_1_results['total'])

#search yelp library for Less Expensive Restaurants ($$)
search_2_results = yelp_api.search_query(term='restaurants', location='chicago, il', price=2)
pprint (search_2_results['total'])

#search yelp library for More Expensive Restaurants ($$$)
search_3_results = yelp_api.search_query(term='restaurants', location='chicago, il', price=3)
pprint (search_3_results['total'])

#search yelp library for Expensive Restaurants ($$$$)
search_4_results = yelp_api.search_query(term='restaurants', location='chicago, il', price=4)
pprint (search_4_results['total'])
# Out:
# 2300
# 2400
# 217
# 48

# %%
# restaurants supporting reservations
print("***** businesses in Chicago supporting restaurant_reservation transactions *****\n{}\n".format("yelp_api.transaction_search_"
                                                                                           "query(transaction_type="
                                                                                           "'restaurant_reservation', location='chicago, il')"))
response = yelp_api.transaction_search_query(transaction_type='restaurant_reservation', location='chicago, il')
pprint(response)
print('\n-------------------------------------------------------------------------\n')
